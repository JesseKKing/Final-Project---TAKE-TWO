# %% [markdown]
# ## Nursing home avaiability in New York!
# I am looking for the different vacancy rates for nursing homes in the Hudson Valley. This data set is from the New York Department of Health's weekly bed census, dated October 23, 2024.

# %%
import pandas as pd

# %%
beds = pd.read_csv("../data/Nursing_Home_Weekly_Bed_Census__Last_Submission_20241023.csv")
beds
# Out:
#      Facility ID                                      Facility Name  \
# 0             38                     Cuba Memorial Hospital Inc SNF
# 1           3902                               Elderwood at Hornell
# 2           3422  St Catherine of Siena Nursing and Rehabilitati...
# 3            244   Humboldt House Rehabilitation and Nursing Center
# 4           8555                            Fox Run at Orchard Park
# ..           ...                                                ...
# 818         1361                     Haym Solomon Home for the Aged
# 819         1103  Hudson Hill Center for Rehabilitation and Nursing
# 820         4772              Rosa Coplon Jewish Home and Infirmary
# 821          677  Clifton Springs Hospital and Clinic Extended Care
# 822          344  Premier Genesee Center for Nursing and Rehabil...
#
#     Certification Number          Street Address             City State  \
# 0               0226000N    140 West Main Street             Cuba    NY
# 1               5034300N      One Bethesda Drive        N Hornell    NY
# 2               5157312N            52 Route 25A        Smithtown    NY
# 3               1401340N         64 Hager Street          Buffalo    NY
# 4               1435304N        One Fox Run Lane     Orchard Park    NY
# ..                   ...                     ...              ...   ...
# 818             7001369N     2340 Cropsey Avenue         Brooklyn    NY
# 819             5907315N     65 Ashburton Avenue          Yonkers    NY
# 820             1451304N  2700 North Forest Road        Getzville    NY
# 821             3421000N          2 Coulter Road  Clifton Springs    NY
# 822             1801308N         278 Bank Street          Batavia    NY
#
#        Zip       County                                        Area Office  \
# 0    14727     Allegany                  Western Regional Office - Buffalo
# 1    14843      Steuben                Western Regional Office - Rochester
# 2    11787      Suffolk    Metropolitan Area Regional Office - Long Island
# 3    14208         Erie                  Western Regional Office - Buffalo
# 4    14127         Erie                  Western Regional Office - Buffalo
# ..     ...          ...                                                ...
# 818  11214        Kings  Metropolitan Area Regional Office - New York City
# 819  10701  Westchester   Metropolitan Area Regional Office - New Rochelle
# 820  14068         Erie                  Western Regional Office - Buffalo
# 821  14432      Ontario                Western Regional Office - Rochester
# 822  14020      Genesee                  Western Regional Office - Buffalo
#
#             Phone  Website Census Date  Week Difference  \
# 0    585-968-2000      NaN  09/25/2024                0
# 1    607-324-6900      NaN  09/25/2024                0
# 2    631-862-3900      NaN  09/25/2024                0
# 3    716-886-4377      NaN  09/25/2024                0
# 4    716-662-5001      NaN  09/25/2024                0
# ..            ...      ...         ...              ...
# 818  718-373-1700      NaN  09/25/2024                0
# 819  914-963-4000      NaN  09/25/2024                0
# 820  716-639-3330      NaN  09/25/2024                0
# 821  315-462-9561      NaN  09/25/2024                0
# 822  585-344-0584      NaN  09/25/2024                0
#
#      Week Difference Category    Bed Type  Total Capacity Available Capacity  \
# 0                           0    NHBEDSAV              61                 22
# 1                           0    NHBEDSAV             112                  6
# 2                           0    NHBEDSAV             240                 40
# 3                           0    NHBEDSAV             173                 29
# 4                           0    NHBEDSAV              60                 10
# ..                        ...         ...             ...                ...
# 818                         0    NHBEDSAV             240                 21
# 819                         0  VENTBEDSAV              10                  9
# 820                         0    NHBEDSAV             180                 49
# 821                         0    NHBEDSAV             108                  2
# 822                         0    NHBEDSAV             147                 13
#
#      Category                      Location
# 0           5  POINT (-78.287506 42.213474)
# 1           3  POINT (-77.660423 42.346268)
# 2           5    POINT (-73.2202 40.867664)
# 3           5  POINT (-78.848213 42.921112)
# 4           4  POINT (-78.774719 42.764557)
# ..        ...                           ...
# 818         5  POINT (-73.995995 40.594852)
# 819         3  POINT (-73.894783 40.939518)
# 820         5  POINT (-78.786102 43.015533)
# 821         1  POINT (-77.138863 42.960537)
# 822         4  POINT (-78.177483 43.008652)
#
# [823 rows x 19 columns]

# %%
beds.columns #What columns are there?
# Out:
# Index(['Facility ID', 'Facility Name', 'Certification Number',
#        'Street Address', 'City', 'State', 'Zip', 'County', 'Area Office',
#        'Phone', 'Website', 'Census Date', 'Week Difference',
#        'Week Difference Category', 'Bed Type', 'Total Capacity',
#        'Available Capacity', 'Category', 'Location'],
#       dtype='object')

# %%
beds.dtypes #What data types are we working with? Note that available capacity is an object...
# Out:
# Facility ID                   int64
# Facility Name                object
# Certification Number         object
# Street Address               object
# City                         object
# State                        object
# Zip                           int64
# County                       object
# Area Office                  object
# Phone                        object
# Website                     float64
# Census Date                  object
# Week Difference               int64
# Week Difference Category      int64
# Bed Type                     object
# Total Capacity                int64
# Available Capacity           object
# Category                      int64
# Location                     object
# dtype: object

# %% [markdown]
# ## Clean Data
# This dataset relies on nursing homes to self-report their availability on a weekly basis. To double-check that there's no null or N/A values in important columns, I used DropNa.

# %%
clean_beds = beds.dropna(subset=["Facility Name", "Certification Number", "County", "Bed Type", "Week Difference Category", "Week Difference", "Total Capacity", "Available Capacity"])

# %%
clean_beds
# Out:
#      Facility ID                                      Facility Name  \
# 0             38                     Cuba Memorial Hospital Inc SNF
# 1           3902                               Elderwood at Hornell
# 2           3422  St Catherine of Siena Nursing and Rehabilitati...
# 3            244   Humboldt House Rehabilitation and Nursing Center
# 4           8555                            Fox Run at Orchard Park
# ..           ...                                                ...
# 818         1361                     Haym Solomon Home for the Aged
# 819         1103  Hudson Hill Center for Rehabilitation and Nursing
# 820         4772              Rosa Coplon Jewish Home and Infirmary
# 821          677  Clifton Springs Hospital and Clinic Extended Care
# 822          344  Premier Genesee Center for Nursing and Rehabil...
#
#     Certification Number          Street Address             City State  \
# 0               0226000N    140 West Main Street             Cuba    NY
# 1               5034300N      One Bethesda Drive        N Hornell    NY
# 2               5157312N            52 Route 25A        Smithtown    NY
# 3               1401340N         64 Hager Street          Buffalo    NY
# 4               1435304N        One Fox Run Lane     Orchard Park    NY
# ..                   ...                     ...              ...   ...
# 818             7001369N     2340 Cropsey Avenue         Brooklyn    NY
# 819             5907315N     65 Ashburton Avenue          Yonkers    NY
# 820             1451304N  2700 North Forest Road        Getzville    NY
# 821             3421000N          2 Coulter Road  Clifton Springs    NY
# 822             1801308N         278 Bank Street          Batavia    NY
#
#        Zip       County                                        Area Office  \
# 0    14727     Allegany                  Western Regional Office - Buffalo
# 1    14843      Steuben                Western Regional Office - Rochester
# 2    11787      Suffolk    Metropolitan Area Regional Office - Long Island
# 3    14208         Erie                  Western Regional Office - Buffalo
# 4    14127         Erie                  Western Regional Office - Buffalo
# ..     ...          ...                                                ...
# 818  11214        Kings  Metropolitan Area Regional Office - New York City
# 819  10701  Westchester   Metropolitan Area Regional Office - New Rochelle
# 820  14068         Erie                  Western Regional Office - Buffalo
# 821  14432      Ontario                Western Regional Office - Rochester
# 822  14020      Genesee                  Western Regional Office - Buffalo
#
#             Phone  Website Census Date  Week Difference  \
# 0    585-968-2000      NaN  09/25/2024                0
# 1    607-324-6900      NaN  09/25/2024                0
# 2    631-862-3900      NaN  09/25/2024                0
# 3    716-886-4377      NaN  09/25/2024                0
# 4    716-662-5001      NaN  09/25/2024                0
# ..            ...      ...         ...              ...
# 818  718-373-1700      NaN  09/25/2024                0
# 819  914-963-4000      NaN  09/25/2024                0
# 820  716-639-3330      NaN  09/25/2024                0
# 821  315-462-9561      NaN  09/25/2024                0
# 822  585-344-0584      NaN  09/25/2024                0
#
#      Week Difference Category    Bed Type  Total Capacity Available Capacity  \
# 0                           0    NHBEDSAV              61                 22
# 1                           0    NHBEDSAV             112                  6
# 2                           0    NHBEDSAV             240                 40
# 3                           0    NHBEDSAV             173                 29
# 4                           0    NHBEDSAV              60                 10
# ..                        ...         ...             ...                ...
# 818                         0    NHBEDSAV             240                 21
# 819                         0  VENTBEDSAV              10                  9
# 820                         0    NHBEDSAV             180                 49
# 821                         0    NHBEDSAV             108                  2
# 822                         0    NHBEDSAV             147                 13
#
#      Category                      Location
# 0           5  POINT (-78.287506 42.213474)
# 1           3  POINT (-77.660423 42.346268)
# 2           5    POINT (-73.2202 40.867664)
# 3           5  POINT (-78.848213 42.921112)
# 4           4  POINT (-78.774719 42.764557)
# ..        ...                           ...
# 818         5  POINT (-73.995995 40.594852)
# 819         3  POINT (-73.894783 40.939518)
# 820         5  POINT (-78.786102 43.015533)
# 821         1  POINT (-77.138863 42.960537)
# 822         4  POINT (-78.177483 43.008652)
#
# [823 rows x 19 columns]

# %% [markdown]
# The number of rows is the same! 823.

# %% [markdown]
# After doing a little digging though, there are some entrys in the "Available Capacity" column that, while not empty, only contain a "." Before I move forward, I need to change any of those periods to "0" in important columns - and I need to change the dtype of "Available Capacity" from an object to an integer, so I can perform calculations with it going forward.

# %%
clean_beds.loc[clean_beds["Available Capacity"] == "."] = 0
clean_beds.loc[clean_beds["Total Capacity"] == "."] = 0

# %%
clean_beds["Available Capacity"] = clean_beds["Available Capacity"].astype(int)

# %%
clean_beds.dtypes #As you can see, "Avialable Capacity" is an integer now.
# Out:
# Facility ID                   int64
# Facility Name                object
# Certification Number         object
# Street Address               object
# City                         object
# State                        object
# Zip                           int64
# County                       object
# Area Office                  object
# Phone                        object
# Website                     float64
# Census Date                  object
# Week Difference               int64
# Week Difference Category      int64
# Bed Type                     object
# Total Capacity                int64
# Available Capacity            int64
# Category                      int64
# Location                     object
# dtype: object

# %% [markdown]
# ## Statewide Math
# I'm going to want this for later: what's the statewide occupancy and vacancy rate? Once I find out, I'll create a nice little dataframe for it.

# %%
statewide_availability = clean_beds["Available Capacity"].sum()

# %%
statewide_capacity = clean_beds["Total Capacity"].sum()

# %%
statewide_vacancy_rate = ((statewide_availability / statewide_capacity) * 100).round(2)
statewide_vacancy_rate
# Out:
# 12.18

# %%
statewide_occupancy_rate = (100 - statewide_vacancy_rate).round(2)
statewide_occupancy_rate
# Out:
# 87.82

# %%
data = {"County": ["Statewide"], "Occupancy Rate" : [statewide_occupancy_rate], "Vacancy Rate" : [statewide_vacancy_rate]}
state_df = pd.DataFrame(data)
state_df
# Out:
#       County  Occupancy Rate  Vacancy Rate
# 0  Statewide           87.82         12.18

# %% [markdown]
# ## Pare Down Data
# Now that I've gotten statewide stuff out of the way, it's time to pare down the dataset to focus on the Hudson Valley. Let's start by selecting the columns I actually want to work with.

# %%
county_beds = clean_beds[["County", "Facility Name", "Available Capacity", "Total Capacity"]]
county_beds
# Out:
#           County                                      Facility Name  \
# 0       Allegany                     Cuba Memorial Hospital Inc SNF
# 1        Steuben                               Elderwood at Hornell
# 2        Suffolk  St Catherine of Siena Nursing and Rehabilitati...
# 3           Erie   Humboldt House Rehabilitation and Nursing Center
# 4           Erie                            Fox Run at Orchard Park
# ..           ...                                                ...
# 818        Kings                     Haym Solomon Home for the Aged
# 819  Westchester  Hudson Hill Center for Rehabilitation and Nursing
# 820         Erie              Rosa Coplon Jewish Home and Infirmary
# 821      Ontario  Clifton Springs Hospital and Clinic Extended Care
# 822      Genesee  Premier Genesee Center for Nursing and Rehabil...
#
#      Available Capacity  Total Capacity
# 0                    22              61
# 1                     6             112
# 2                    40             240
# 3                    29             173
# 4                    10              60
# ..                  ...             ...
# 818                  21             240
# 819                   9              10
# 820                  49             180
# 821                   2             108
# 822                  13             147
#
# [823 rows x 4 columns]

# %% [markdown]
# The Hudson Valley has nine counties: Columbia, Dutchess, Greene, Orange, Putnam, Rockland, Sullivan, Ulster, and Westchester. So I can drop any rows from outside counties.

# %%
hudson_beds = county_beds[county_beds["County"].isin(["Columbia", "Dutchess", "Greene", "Orange", "Putnam", "Rockland", "Sullivan", "Ulster", "Westchester"])]
hudson_beds
# Out:
#           County                                      Facility Name  \
# 6    Westchester       Sans Souci Rehabilitation and Nursing Center
# 8    Westchester      Adira at Riverside Rehabilitation and Nursing
# 9         Greene  The Pines at Catskill Center for Nursing & Reh...
# 11   Westchester               White Plains Center for Nursing Care
# 29   Westchester           New York State Veterans Home at Montrose
# ..           ...                                                ...
# 785     Dutchess                     The Baptist Home at Brookmeade
# 791  Westchester        Tarrytown Rehabilitation and Nursing Center
# 799       Ulster  Northeast Center for Rehabilitation and Brain ...
# 803  Westchester                     United Hebrew Geriatric Center
# 819  Westchester  Hudson Hill Center for Rehabilitation and Nursing
#
#      Available Capacity  Total Capacity
# 6                     9             120
# 8                     4             120
# 9                     6             136
# 11                    5              88
# 29                   54             252
# ..                  ...             ...
# 785                  41              45
# 791                   5             120
# 799                   0              20
# 803                 121             296
# 819                   9              10
#
# [121 rows x 4 columns]

# %% [markdown]
# ## Time to do some math!
#
# Now it's time to group all the nursing homes by county, add up their beds, and calculate their vacancy / occupancy rates. In my initial analysis, I did this individually, repeating the same long process (like what I did for the statewide calculation above) county by county. This time around, I'll use groupby to essentially put together a pivot table. I'll then add columns to it with calculations as needed.

# %%
pivot_table = hudson_beds.groupby(["County"], as_index=False).agg({
    "Available Capacity" : "sum", 
    "Total Capacity" : "sum", 
})

pivot_table
# Out:
#         County  Available Capacity  Total Capacity
# 0     Columbia                  40             728
# 1     Dutchess                 328            2064
# 2       Greene                  28             256
# 3       Orange                 284            1434
# 4       Putnam                  48             320
# 5     Rockland                 226            1599
# 6     Sullivan                  55             401
# 7       Ulster                 259            1509
# 8  Westchester                1034            7508

# %%
#Calculating vacancy rates
pivot_table["Vacancy Rate"] = pivot_table["Available Capacity"] / pivot_table["Total Capacity"] * 100
pivot_table
# Out:
#         County  Available Capacity  Total Capacity  Vacancy Rate
# 0     Columbia                  40             728      5.494505
# 1     Dutchess                 328            2064     15.891473
# 2       Greene                  28             256     10.937500
# 3       Orange                 284            1434     19.804742
# 4       Putnam                  48             320     15.000000
# 5     Rockland                 226            1599     14.133834
# 6     Sullivan                  55             401     13.715711
# 7       Ulster                 259            1509     17.163685
# 8  Westchester                1034            7508     13.771977

# %%
#Calculating occupancy rates
pivot_table["Occupancy Rate"] = 100 - pivot_table["Vacancy Rate"]
pivot_table
# Out:
#         County  Available Capacity  Total Capacity  Vacancy Rate  \
# 0     Columbia                  40             728      5.494505
# 1     Dutchess                 328            2064     15.891473
# 2       Greene                  28             256     10.937500
# 3       Orange                 284            1434     19.804742
# 4       Putnam                  48             320     15.000000
# 5     Rockland                 226            1599     14.133834
# 6     Sullivan                  55             401     13.715711
# 7       Ulster                 259            1509     17.163685
# 8  Westchester                1034            7508     13.771977
#
#    Occupancy Rate
# 0       94.505495
# 1       84.108527
# 2       89.062500
# 3       80.195258
# 4       85.000000
# 5       85.866166
# 6       86.284289
# 7       82.836315
# 8       86.228023

# %%
#These percentages are long, let's round them.
pivot_table["Vacancy Rate"] = pivot_table["Vacancy Rate"].round(2) 
pivot_table["Occupancy Rate"] = pivot_table["Occupancy Rate"].round(2) 
pivot_table
# Out:
#         County  Available Capacity  Total Capacity  Vacancy Rate  \
# 0     Columbia                  40             728          5.49
# 1     Dutchess                 328            2064         15.89
# 2       Greene                  28             256         10.94
# 3       Orange                 284            1434         19.80
# 4       Putnam                  48             320         15.00
# 5     Rockland                 226            1599         14.13
# 6     Sullivan                  55             401         13.72
# 7       Ulster                 259            1509         17.16
# 8  Westchester                1034            7508         13.77
#
#    Occupancy Rate
# 0           94.51
# 1           84.11
# 2           89.06
# 3           80.20
# 4           85.00
# 5           85.87
# 6           86.28
# 7           82.84
# 8           86.23

# %% [markdown]
# Now that I'm done doing math, I can drop the "Available Capacity" and "Total Capacity" columns. For my final graphic in DataWrapper, I just want the occupancy / vacancy rates.

# %%
df = pivot_table[["County", "Occupancy Rate", "Vacancy Rate"]]
df #Yay!
# Out:
#         County  Occupancy Rate  Vacancy Rate
# 0     Columbia           94.51          5.49
# 1     Dutchess           84.11         15.89
# 2       Greene           89.06         10.94
# 3       Orange           80.20         19.80
# 4       Putnam           85.00         15.00
# 5     Rockland           85.87         14.13
# 6     Sullivan           86.28         13.72
# 7       Ulster           82.84         17.16
# 8  Westchester           86.23         13.77

# %% [markdown]
# Remember the statewide dataframe from earlier? I want to tack that on to the Hudson Valley dataframe here, just to have the comparison for the DataWrapper graphic.

# %%
df = pd.concat([df, state_df], ignore_index=True)

# %%
df
# Out:
#         County  Occupancy Rate  Vacancy Rate
# 0     Columbia           94.51          5.49
# 1     Dutchess           84.11         15.89
# 2       Greene           89.06         10.94
# 3       Orange           80.20         19.80
# 4       Putnam           85.00         15.00
# 5     Rockland           85.87         14.13
# 6     Sullivan           86.28         13.72
# 7       Ulster           82.84         17.16
# 8  Westchester           86.23         13.77
# 9    Statewide           87.82         12.18

# %% [markdown]
# Time to write to CSV!

# %%
df.to_csv("HV_Nursing_Home_Vacancies.csv", index=False) #Huzzah
